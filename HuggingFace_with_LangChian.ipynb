# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# ## Access HuggingFace Models with API

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
api_key = userdata.get('HF_Token')

# %%
import os

os.environ['HF_Token']=api_key

# %%
repo = 'deepseek-ai/DeepSeek-R1'

repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    task="text-generation",
    max_length=128,
    temperature=0.5,
    huggingfacehub_api_token=api_key,
)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.

# %%
llm.invoke("What is Managing AI in Business?")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %%
from IPython.display import Markdown
Markdown(llm.invoke("What is Managing AI in Business?"))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
#  Managing AI in Business is a process of integrating artificial intelligence (AI) into business operations to improve efficiency, accuracy, and decision-making. While AI can automate many tasks, it also requires human oversight and management. Here are some key aspects of managing AI in business:
#
# 1. **Strategy and Planning:**
#    - Identify areas where AI can provide value.
#    - Define clear objectives and KPIs for AI projects.
# ...

# %%
repo_id = 'deepseek-ai/DeepSeek-R1'
llm2 = HuggingFaceEndpoint(
    repo_id=repo,
    task="text-generation",
    max_length=128,
    temperature=0.5,
    huggingfacehub_api_token=api_key,
)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.

# %%
Markdown(llm2.invoke("What is Managing Generative AI in Business?"))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
#  Generative AI, such as the one used to create this response, can generate new, synthetic yet human-like text based on the input it receives. This technology has significant implications for businesses, offering opportunities for content creation, customer engagement, and more. However, managing generative AI in a business context also presents challenges and considerations. Here are some key aspects to consider:
#
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="What are some common AI use cases in business?"
template = """Question: {question}
Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain = LLMChain(llm=llm, prompt=prompt)
Markdown(llm_chain.run(question))
# Out:
# <ipython-input-32-d70a5a2e3d10>:2: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   Markdown(llm_chain.run(question))
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
#  AI can be used in various ways in business. Here are some common use cases:
#
# 1. **Customer Service:**
# ...

# %% [markdown]
# ## HuggingFace Pipeline
# These pipelines are objects that abstract most of the complex code from the library, offering a simple API dedicated to several tasks, including Named Entity Recognition, Masked Language Modeling, Sentiment Analysis, Feature Extraction and Question Answering.

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id = "gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)
# Out:
# Device set to use cpu

# %%
Markdown(hf.invoke("What is Managing AI in Business?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is Managing AI in Business?
#
# AI is becoming less and less common. We see companies that specialize in managing tasks such as customer service and customer service management and sales, technology and service analytics. We also see companies that specialize in AI and the automation and automation features of AI, such as AI management and automated testing automation. It appears that business needs AI as a means to solve problems, make business decisions and to learn all that is needed to create new business opportunities. The main problem is AI, is it not?

# %%
# Huggingface Pipeline with GPU

gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device_map="auto",  # Use device_map="auto" for automatic device selection
    pipeline_kwargs={"max_new_tokens": 100},
)
# Out:
# Device set to use cpu

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt | gpu_llm

# %%
question = 'What is Managing AI in Business?'
Markdown(chain.invoke({"question":question}))
# Out:
# Question: What is Managing AI in Business?
#
# Answer: Let's think step by step. We have a machine which does some stuff to find new information and that is, we start making a decision that we want to use as the next thing to help us deal with this information, the information that we are dealing with. It isn't until the customer has something to give us then we create something new.
#
# When we are making this decision we need to first create a new feature, the system may not be fully familiar with the technology, we may have some limitations, what we are
